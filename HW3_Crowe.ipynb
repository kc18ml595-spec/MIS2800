# %% [markdown]
# <a href="https://colab.research.google.com/github/kc18ml595-spec/MIS2800/blob/main/HW3_Crowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 74.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('AdCampaigns.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %%
# %%sql
# CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 15000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 5000000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands ORDER BY brand_name
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (7, 'Google', 'Technology', 8000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (6, 'IBM', 'Technology', 100000),
#  (3, 'Pepsi', 'Beverages', 2000000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands
# WHERE brand_type = 'Religious'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands
# WHERE brand_name = 'budget'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# SELECT * FROM Marketing_Brands
# WHERE brand_type = 'Snacks' OR brand_type = 'Beverages'
# ORDER BY brand_type
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands
# ORDER BY brand_budget DESC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000),
#  (7, 'Google', 'Technology', 8000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (6, 'IBM', 'Technology', 100000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %% [markdown]
# Block 1: Added the word TABLE between SELECT * and Marketing_Brands
#
# Block 2: Add the word INTO between INSERT and Marketing_brands
#
# Block 3: Needed to add * between SELECT and FROM
#
# Block 4: Include * between SELECT and FROM. Add a line below and enter "ORDER BY brand_name"
#
# Block 5: Add * between SELECT and FROM. Add a line below and add "WHERE brand_type = 'Religious'"
#
# Block 6: Add * between SELECT and FROM. Add a line below and enter "WHERE brand_name = 'budget'"
#
# Block 7: Add * between SELECT and FROM. Add a line below and enter "WHERE brand_type = 'Snacks' OR brand_type = 'Beverages'." Add another line saying ORDER BY brand_type.
#
# Block 8: Include %%sql
#
# Block 9: Add %%sql. Enter "SELECT * Marketing_Brands". Add a line below and enter "ORDER BY brand_budget DESC"
#
# Block 10: Enter "SELECT * FROM Marketing_Brands".
